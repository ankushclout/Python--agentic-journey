# %%
print("Hello World")
# Out:
# Hello World

# %%
movies = []
mov1 = input("enter first")
mov2 = input("enter second")
mov3 = input("enter third")

movies.append(mov1)
movies.append(mov2)
movies.append(mov3)

print(movies)
# Out:
# ['a', 'b', 'c']

# %%
movies = []
movies.append(input("enter first"))
movies.append(input("enter second"))
movies.append(input("enter third"))

print(movies)
# Out:
# ['a', 'b', 'c']
